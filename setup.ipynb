# %%
# %sql
CREATE CATALOG hr_catalog_divansh;

USE CATALOG hr_catalog_divansh;

CREATE SCHEMA bronze;

CREATE TABLE bronze.employees (
  employee_id STRING,
  name STRING
);

# %%
dbutils.fs.mkdirs("/FileStore/hr_divansh/raw/")

# %%
dbutils.fs.ls("/FileStore/hr_divansh/raw/")
